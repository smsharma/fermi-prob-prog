# %%
# %reload_ext autoreload
# %autoreload 2

import os, sys
sys.path.append("..")

import numpy as np
import healpy as hp
from astropy.io import fits
from pprint import pprint
from tqdm import tqdm

from scipy import optimize
from scipy.stats import poisson

# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc_file('../notebooks/matplotlibrc')

# %%
from models.ebin_poisson_model import EbinPoissonModel

# %%
ebinmodel = EbinPoissonModel(
    nside = 128,
    dif_name = 'ccwa',
    bulge_name = 'mcdermott2022',
)
# Out:
# Loading... 0
# counts
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_12518/3527355454.py in <module>
#       2     nside = 128,
#       3     dif_name = 'ccwa',
# ----> 4     bulge_name = 'mcdermott2022',
#       5 )
#
# /zfs/yitians/fermi/fermi-prob-prog/models/ebin_poisson_model.py in __init__(self, nside, ps_cat, data_class, temp_class, mask_class, mask_roi_r_outer, mask_roi_b, dif_names, dif_name, bulge_names, bulge_name)
#      77         print(np.sum(self.counts))
#      78         print('counts', end=' ', flush=True)
# ---> 79         self.exposure = to_nside(np.load(f'{self.data_dir}/exposure-{self.data_class}.npy'))
#      80         print('exposure', end=' ', flush=True)
#      81
#
# /zfs/yitians/fermi/fermi-prob-prog/models/ebin_poisson_model.py in <lambda>(x)
#      64         #========== General ==========
#      65         self.nside = nside
# ---> 66         to_nside = lambda x: hp.pixelfunc.ud_grade(x, self.nside)
#      67         self.ps_cat = ps_cat
#      68         self.data_class = data_class
#
# /zfs/yitians/anaconda3/envs/fermi/lib/python3.7/site-packages/healpy/pixelfunc.py in wrapper(map_in, *args, **kwds)
#     302         return_ma = is_ma(map_in)
#     303         m = ma_to_array(map_in)
# --> 304         out = f(m, *args, **kwds)
#     305         return ma(out) if return_ma else out
#     306
#
# /zfs/yitians/anaconda3/envs/fermi/lib/python3.7/site-packages/healpy/pixelfunc.py in ud_grade(map_in, nside_out, pess, order_in, order_out, power, dtype)
#    1938     for m in m_in:
#    1939         if str(order_in).upper()[0:4] == "RING":
# -> 1940             m = reorder(m, r2n=True)
#    1941         mout = _ud_grade_core(m, nside_out, pess=pess, power=power, dtype=dtype)
#    1942         if str(order_out).upper()[0:4] == "RING":
#
# /zfs/yitians/anaconda3/envs/fermi/lib/python3.7/site-packages/healpy/pixelfunc.py in wrapper(map_in, *args, **kwds)
#     302         return_ma = is_ma(map_in)
#     303         m = ma_to_array(map_in)
# --> 304         out = f(m, *args, **kwds)
#     305         return ma(out) if return_ma else out
#     306
#
# /zfs/yitians/anaconda3/envs/fermi/lib/python3.7/site-packages/healpy/pixelfunc.py in reorder(map_in, inp, out, r2n, n2r)
#     922                 ipix_n = np.arange(ibunch * bunchsize, (ibunch + 1) * bunchsize)
#     923                 ipix_r = nest2ring(nside, ipix_n)
# --> 924                 m_out[ipix_n] = np.asarray(m_in)[ipix_r]
#     925             mapout.append(m_out)
#     926         elif inp == "NEST":
#
# KeyboardInterrupt:

# %%
from scipy import optimize

# %%
bounds = tuple([(0, 10) for _ in range(8)])
use_sho = True
if use_sho:
    result = optimize.shgo(ebinmodel.log_likelihood, bounds=bounds, args=())
else:
    x0 = np.ones((8,))
    result = optimize.minimize(ebinmodel.log_likelihood, x0=x0, bounds=bounds, args=())

# %%
result.x
# Out:
# array([0., 0., 0., 0., 0., 0., 0., 0.])

# %%
ebinmodel.log_likelihood(np.ones(8)*0.001)
# Out:
# 0.0977340273896217

# %%
np.sum(ebinmodel.counts)
# Out:
# 0

# %%
np.array(to_nside(np.load(f'{self.data_dir}/counts-{self.data_class}.npy')).astype(np.int32))

# %%
from
