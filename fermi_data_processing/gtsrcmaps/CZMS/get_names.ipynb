# %%
import numpy as np
import re

# %%
tag_list = []
with open('/data/submit/yitians/fermi/templates/CZMS/NAMING_CONVENTION_OF_DIFFUSE_EMISSION_MODELS.dat') as file:
    rows = file.readlines()
    for row in rows[1:]:
        r = re.sub(r"\s+", " ", row)
        tag_list.append(r.split(' ')[1])

# %%
print('\''+'\' \''.join(tag_list)+'\'')
# Out:
# 'bs' '0w' '5q' '9l' '9z' 'bh' 'ba' '22' '23' 'ch' '24' '26' '2c' '2e' 'c4' '2g' '2i' '2p' '2q' '2r' '2s' '2t' '2u' '2v' '2w' '2y' '2z' '30' '31' '32' '3j' '3z' '5s' '67' '6e' '6n' '6z' '70' '71' '7c' '7n' '7o' '7p' '7t' '7u' '80' '8f' '8l' '8t' '93' 'au' 'ay' 'bf' 'cg' 'cv' 'd1' 'dy' '0a' '0b' '0c' '0g' '0t' '0u' '0v' '14' '1c' '1d' '1e' '1i' '1j' '1k' '1nB' '1oB' '1pB' '1qB' '1rB' '1sB' '1xB' '1yB' '1zB'

# %%
print('\''+'\', \''.join(tag_list)+'\'')
# Out:
# 'bs', '0w', '5q', '9l', '9z', 'bh', 'ba', '22', '23', 'ch', '24', '26', '2c', '2e', 'c4', '2g', '2i', '2p', '2q', '2r', '2s', '2t', '2u', '2v', '2w', '2y', '2z', '30', '31', '32', '3j', '3z', '5s', '67', '6e', '6n', '6z', '70', '71', '7c', '7n', '7o', '7p', '7t', '7u', '80', '8f', '8l', '8t', '93', 'au', 'ay', 'bf', 'cg', 'cv', 'd1', 'dy', '0a', '0b', '0c', '0g', '0t', '0u', '0v', '14', '1c', '1d', '1e', '1i', '1j', '1k', '1nB', '1oB', '1pB', '1qB', '1rB', '1sB', '1xB', '1yB', '1zB'
