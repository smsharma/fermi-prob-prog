# %%
import numpy as np
import matplotlib.pyplot as plt
import healpy as hp

# %%
z = hp.ud_grade(np.load("psc_NSIDE512.npy"), 128)
z2 = hp.ud_grade(np.load("../fermi_data_573w/fermi_data_128/template_psc_3fgl.npy"), 128)
z3 = hp.ud_grade(np.load("../fermi_data_573w/fermi_data_128/fermidata_pscmask_3fgl.npy"), 128)

# %%
np.min(z2)
# Out:
# 5.703240949210976e-09

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
# plt.sca(axs[0])
# hp.cartview(hp.ud_grade(z, 128), lonra=[-25,25], latra=[-25,25], norm='log', hold=True)
plt.sca(axs[0])
hp.cartview(z2, lonra=[-25, 25], latra=[-25, 25], norm='log', hold=True)
plt.sca(axs[1])
hp.cartview(z3, lonra=[-25, 25], latra=[-25, 25], hold=True)
plt.sca(axs[2])
hp.cartview(np.clip(z2 * (1-z3), 1e-10, None), lonra=[-25, 25], latra=[-25, 25], norm='log', hold=True)
